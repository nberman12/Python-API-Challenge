# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
import matplotlib.dates as mdate
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 585

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create a base url
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

# Create the lists to hold relative data
cities_list= []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print("Started")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = base_url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    #print(response)
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase city counter
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        cities_list.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
        
print("Completed")
# Out:
# Started
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | nemuro
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | bourail
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | altamira
# Processing Record 10 of Set 1 | sioux lookout
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | mananara
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | komsomolskiy
# Processing Record 15 of Set 1 | kavaratti
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | teguldet
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 1 | mecca
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | chapais
# Processing Record 25 of Set 1 | vostok
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | tigil
# Processing Record 30 of Set 1 | pangnirtung
# Processing Record 31 of Set 1 | altoona
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | winchester
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | merauke
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | zhangjiakou
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | new waterford
# Processing Record 49 of Set 1 | lagoa vermelha
# Processing Record 50 of Set 1 | hasaki
# Processing Record 1 of Set 2 | vila velha
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | qasigiannguit
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | nelson bay
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | sistranda
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | tateyama
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | alice springs
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | kenai
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | dakoro
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | mandalgovi
# Processing Record 21 of Set 2 | novooleksiyivka
# Processing Record 22 of Set 2 | sola
# Processing Record 23 of Set 2 | bainbridge
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | dvinskoy
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | coahuayana
# Processing Record 30 of Set 2 | lasa
# Processing Record 31 of Set 2 | honningsvag
# Processing Record 32 of Set 2 | quatre cocos
# Processing Record 33 of Set 2 | kamina
# Processing Record 34 of Set 2 | nerchinskiy zavod
# Processing Record 35 of Set 2 | tiassale
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | santa vitoria do palmar
# Processing Record 38 of Set 2 | tchibanga
# Processing Record 39 of Set 2 | moose factory
# Processing Record 40 of Set 2 | perpignan
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | buchanan
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | hualmay
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | bad krozingen
# Processing Record 47 of Set 2 | la candelaria
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | nakamura
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | nhulunbuy
# Processing Record 2 of Set 3 | saint pete beach
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | minab
# Processing Record 5 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | kinablangan
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | carutapera
# Processing Record 11 of Set 3 | new delhi
# Processing Record 12 of Set 3 | karratha
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | naze
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | baherden
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | angoche
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | broken hill
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | misratah
# Processing Record 26 of Set 3 | hami
# Processing Record 27 of Set 3 | awjilah
# Processing Record 28 of Set 3 | ndola
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | ventspils
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | hokitika
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | almaznyy
# Processing Record 41 of Set 3 | san giovanni in fiore
# Processing Record 42 of Set 3 | chicama
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | rocha
# Processing Record 46 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 3 | suez
# Processing Record 48 of Set 3 | punta umbria
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | trairi
# Processing Record 3 of Set 4 | kirakira
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | hobyo
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | vardo
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 4 | quixada
# Processing Record 12 of Set 4 | menongue
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | port hope
# Processing Record 15 of Set 4 | weyburn
# Processing Record 16 of Set 4 | vadso
# Processing Record 17 of Set 4 | tual
# Processing Record 18 of Set 4 | heidelberg
# Processing Record 19 of Set 4 | umm lajj
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | camana
# Processing Record 22 of Set 4 | yuancheng
# Processing Record 23 of Set 4 | omaruru
# Processing Record 24 of Set 4 | gimli
# Processing Record 25 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 4 | dikson
# Processing Record 27 of Set 4 | juegang
# Processing Record 28 of Set 4 | that phanom
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | west bay
# Processing Record 33 of Set 4 | hobart
# Processing Record 34 of Set 4 | mingshui
# Processing Record 35 of Set 4 | oga
# Processing Record 36 of Set 4 | kysyl-syr
# Processing Record 37 of Set 4 | auki
# Processing Record 38 of Set 4 | srednekolymsk
# Processing Record 39 of Set 4 | luangwa
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | cruden bay
# City not found. Skipping...
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | butaritari
# Processing Record 44 of Set 4 | lubango
# Processing Record 45 of Set 4 | jardim
# Processing Record 46 of Set 4 | zhezkazgan
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | dano
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | san jose
# Processing Record 1 of Set 5 | acapulco
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 5 | jorpeland
# Processing Record 5 of Set 5 | puerto ayora
# Processing Record 6 of Set 5 | leshukonskoye
# Processing Record 7 of Set 5 | ambon
# Processing Record 8 of Set 5 | scottsbluff
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | po
# City not found. Skipping...
# Processing Record 11 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 5 | kibala
# Processing Record 13 of Set 5 | roma
# Processing Record 14 of Set 5 | sobrance
# Processing Record 15 of Set 5 | calamar
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | woodward
# Processing Record 19 of Set 5 | havoysund
# Processing Record 20 of Set 5 | tuy hoa
# Processing Record 21 of Set 5 | samarai
# Processing Record 22 of Set 5 | san quintin
# Processing Record 23 of Set 5 | miandrivazo
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | varhaug
# Processing Record 26 of Set 5 | sechura
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | dhone
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | esperance
# Processing Record 31 of Set 5 | zabol
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | faya
# Processing Record 35 of Set 5 | maloy
# Processing Record 36 of Set 5 | khash
# Processing Record 37 of Set 5 | natal
# Processing Record 38 of Set 5 | burnie
# Processing Record 39 of Set 5 | kitimat
# Processing Record 40 of Set 5 | broome
# Processing Record 41 of Set 5 | hailun
# Processing Record 42 of Set 5 | tabou
# Processing Record 43 of Set 5 | jumla
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | inuvik
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | derzhavinsk
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | shimoda
# Processing Record 50 of Set 5 | vao
# Processing Record 1 of Set 6 | nyimba
# Processing Record 2 of Set 6 | sisimiut
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | kalmunai
# Processing Record 5 of Set 6 | tommot
# Processing Record 6 of Set 6 | san policarpo
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | la ronge
# Processing Record 9 of Set 6 | berdigestyakh
# Processing Record 10 of Set 6 | marquette
# Processing Record 11 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 6 | ostrovnoy
# Processing Record 13 of Set 6 | tagusao
# Processing Record 14 of Set 6 | calatayud
# Processing Record 15 of Set 6 | cuamba
# Processing Record 16 of Set 6 | berlevag
# Processing Record 17 of Set 6 | aksarka
# Processing Record 18 of Set 6 | aasiaat
# Processing Record 19 of Set 6 | los banos
# Processing Record 20 of Set 6 | avarua
# Processing Record 21 of Set 6 | taruma
# Processing Record 22 of Set 6 | teguise
# Processing Record 23 of Set 6 | altea
# Processing Record 24 of Set 6 | sao jose da coroa grande
# Processing Record 25 of Set 6 | lavrentiya
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | abu zabad
# Processing Record 28 of Set 6 | edgewater
# Processing Record 29 of Set 6 | saladoblanco
# Processing Record 30 of Set 6 | barra patuca
# Processing Record 31 of Set 6 | tayturka
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | boa vista
# Processing Record 35 of Set 6 | borshchiv
# Processing Record 36 of Set 6 | bobrovka
# Processing Record 37 of Set 6 | bulancak
# Processing Record 38 of Set 6 | nome
# Processing Record 39 of Set 6 | bintulu
# Processing Record 40 of Set 6 | deputatskiy
# Processing Record 41 of Set 6 | mokhsogollokh
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | niihama
# Processing Record 44 of Set 6 | vestmannaeyjar
# Processing Record 45 of Set 6 | urusha
# Processing Record 46 of Set 6 | saldanha
# Processing Record 47 of Set 6 | westport
# Processing Record 48 of Set 6 | guozhen
# Processing Record 49 of Set 6 | oni
# Processing Record 50 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 7 | smithers
# Processing Record 2 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 7 | puerto narino
# Processing Record 4 of Set 7 | georgetown
# Processing Record 5 of Set 7 | north bend
# Processing Record 6 of Set 7 | ortigueira
# Processing Record 7 of Set 7 | marawi
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | tautira
# Processing Record 10 of Set 7 | loum
# Processing Record 11 of Set 7 | paysandu
# Processing Record 12 of Set 7 | ilheus
# Processing Record 13 of Set 7 | northam
# Processing Record 14 of Set 7 | makakilo city
# Processing Record 15 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 16 of Set 7 | takaka
# Processing Record 17 of Set 7 | hof
# Processing Record 18 of Set 7 | anloga
# Processing Record 19 of Set 7 | yunhe
# Processing Record 20 of Set 7 | russell
# Processing Record 21 of Set 7 | craig
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | college
# Processing Record 24 of Set 7 | yarmouth
# Processing Record 25 of Set 7 | georgiyevka
# Processing Record 26 of Set 7 | isangel
# Processing Record 27 of Set 7 | novobirilyussy
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | dubrovka
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | tomatlan
# Processing Record 32 of Set 7 | lagoa
# Processing Record 33 of Set 7 | poum
# Processing Record 34 of Set 7 | itarema
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | norwich
# Processing Record 37 of Set 7 | faanui
# Processing Record 38 of Set 7 | valparaiso
# Processing Record 39 of Set 7 | malakal
# Processing Record 40 of Set 7 | katha
# City not found. Skipping...
# Processing Record 41 of Set 7 | navsari
# Processing Record 42 of Set 7 | uk
# City not found. Skipping...
# Processing Record 43 of Set 7 | souillac
# Processing Record 44 of Set 7 | longido
# Processing Record 45 of Set 7 | port elizabeth
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | datong
# Processing Record 48 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 49 of Set 7 | puerto leguizamo
# Processing Record 50 of Set 7 | mao
# Processing Record 1 of Set 8 | zhigansk
# Processing Record 2 of Set 8 | sao marcos
# Processing Record 3 of Set 8 | madison heights
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | piacabucu
# Processing Record 6 of Set 8 | dargaville
# Processing Record 7 of Set 8 | les cayes
# Processing Record 8 of Set 8 | pevek
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | moranbah
# Processing Record 12 of Set 8 | rupert
# Processing Record 13 of Set 8 | dakar
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | orlik
# Processing Record 16 of Set 8 | yar-sale
# Processing Record 17 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 8 | yumen
# Processing Record 19 of Set 8 | sur
# Processing Record 20 of Set 8 | borama
# City not found. Skipping...
# Processing Record 21 of Set 8 | cabrobo
# Processing Record 22 of Set 8 | sirisia
# City not found. Skipping...
# Processing Record 23 of Set 8 | newtownards
# Processing Record 24 of Set 8 | helong
# Processing Record 25 of Set 8 | kathmandu
# Processing Record 26 of Set 8 | sandwick
# Processing Record 27 of Set 8 | tombouctou
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | dombarovskiy
# Processing Record 31 of Set 8 | kajaani
# Processing Record 32 of Set 8 | san roque
# Processing Record 33 of Set 8 | rolla
# Processing Record 34 of Set 8 | hastings
# Processing Record 35 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 8 | acatlan
# Processing Record 37 of Set 8 | tiznit
# Processing Record 38 of Set 8 | iskateley
# Processing Record 39 of Set 8 | homer
# Processing Record 40 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | shiyan
# Processing Record 43 of Set 8 | teya
# Processing Record 44 of Set 8 | beinamar
# Processing Record 45 of Set 8 | mongo
# Processing Record 46 of Set 8 | manta
# Processing Record 47 of Set 8 | sadiqabad
# Processing Record 48 of Set 8 | krasnoselkup
# Processing Record 49 of Set 8 | troitskoye
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 9 | castlebar
# Processing Record 3 of Set 9 | zyryanka
# Processing Record 4 of Set 9 | bom jesus
# Processing Record 5 of Set 9 | coffs harbour
# Processing Record 6 of Set 9 | muchkapskiy
# Processing Record 7 of Set 9 | pangkalanbuun
# Processing Record 8 of Set 9 | oktyabrskoye
# Processing Record 9 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | irbeyskoye
# Processing Record 12 of Set 9 | hit
# Processing Record 13 of Set 9 | inverness
# Processing Record 14 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 15 of Set 9 | avera
# Processing Record 16 of Set 9 | svay rieng
# Processing Record 17 of Set 9 | buta
# Processing Record 18 of Set 9 | half moon bay
# Processing Record 19 of Set 9 | port hawkesbury
# Processing Record 20 of Set 9 | biltine
# Processing Record 21 of Set 9 | lokoja
# Processing Record 22 of Set 9 | curup
# Processing Record 23 of Set 9 | bathsheba
# Processing Record 24 of Set 9 | saint-augustin
# Processing Record 25 of Set 9 | anavra
# Processing Record 26 of Set 9 | nam som
# Processing Record 27 of Set 9 | gamba
# Processing Record 28 of Set 9 | shubarkuduk
# Processing Record 29 of Set 9 | san pedro de los naranjos
# Processing Record 30 of Set 9 | tshikapa
# Processing Record 31 of Set 9 | meinung
# City not found. Skipping...
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | luwuk
# Processing Record 34 of Set 9 | maizuru
# Processing Record 35 of Set 9 | fortuna
# Processing Record 36 of Set 9 | marsta
# Processing Record 37 of Set 9 | sterlibashevo
# Processing Record 38 of Set 9 | verkh-usugli
# Processing Record 39 of Set 9 | porto walter
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | ambilobe
# Processing Record 42 of Set 9 | belgrade
# Processing Record 43 of Set 9 | romny
# Processing Record 44 of Set 9 | vanersborg
# Processing Record 45 of Set 9 | vila do maio
# Processing Record 46 of Set 9 | bongandanga
# Processing Record 47 of Set 9 | shimanovsk
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 9 | constitucion
# Processing Record 1 of Set 10 | zambezi
# Processing Record 2 of Set 10 | mangrol
# Processing Record 3 of Set 10 | urucara
# Processing Record 4 of Set 10 | koupela
# Processing Record 5 of Set 10 | junin
# Processing Record 6 of Set 10 | sabang
# Processing Record 7 of Set 10 | noumea
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | diamantino
# Processing Record 10 of Set 10 | carikar
# City not found. Skipping...
# Processing Record 11 of Set 10 | salalah
# Processing Record 12 of Set 10 | beaverlodge
# Processing Record 13 of Set 10 | kupang
# Processing Record 14 of Set 10 | villa altagracia
# Processing Record 15 of Set 10 | margate
# Processing Record 16 of Set 10 | panguna
# Processing Record 17 of Set 10 | vuktyl
# Processing Record 18 of Set 10 | kedrovyy
# Processing Record 19 of Set 10 | taboga
# Processing Record 20 of Set 10 | labytnangi
# Processing Record 21 of Set 10 | edd
# Processing Record 22 of Set 10 | huilong
# Processing Record 23 of Set 10 | kalakamati
# Processing Record 24 of Set 10 | upata
# Processing Record 25 of Set 10 | holme
# Processing Record 26 of Set 10 | santiago
# Processing Record 27 of Set 10 | ranong
# Processing Record 28 of Set 10 | sinzig
# Processing Record 29 of Set 10 | bullhead city
# Processing Record 30 of Set 10 | tepango
# Processing Record 31 of Set 10 | sorong
# Processing Record 32 of Set 10 | talaja
# Processing Record 33 of Set 10 | tuatapere
# Processing Record 34 of Set 10 | samana
# Processing Record 35 of Set 10 | talcahuano
# Processing Record 36 of Set 10 | dawlatabad
# Processing Record 37 of Set 10 | eydhafushi
# Processing Record 38 of Set 10 | medea
# Processing Record 39 of Set 10 | kanungu
# Processing Record 40 of Set 10 | santa cruz de la palma
# Processing Record 41 of Set 10 | bressanone
# Processing Record 42 of Set 10 | eureka
# Processing Record 43 of Set 10 | ruwi
# Processing Record 44 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 10 | suluova
# Processing Record 46 of Set 10 | marsabit
# Processing Record 47 of Set 10 | filadelfia
# Processing Record 48 of Set 10 | alta
# Processing Record 49 of Set 10 | acari
# Processing Record 50 of Set 10 | abu samrah
# Processing Record 1 of Set 11 | minudasht
# Processing Record 2 of Set 11 | genhe
# Processing Record 3 of Set 11 | kaduqli
# Processing Record 4 of Set 11 | vila franca do campo
# Processing Record 5 of Set 11 | ati
# Processing Record 6 of Set 11 | curaca
# Processing Record 7 of Set 11 | nizhniy ufaley
# Processing Record 8 of Set 11 | narsaq
# Processing Record 9 of Set 11 | kasongo
# Processing Record 10 of Set 11 | buala
# Processing Record 11 of Set 11 | la rioja
# Processing Record 12 of Set 11 | antofagasta
# Processing Record 13 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 11 | beian
# Processing Record 15 of Set 11 | sorrento
# Processing Record 16 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | aquidauana
# Processing Record 18 of Set 11 | new philadelphia
# Processing Record 19 of Set 11 | hambantota
# Processing Record 20 of Set 11 | menzelinsk
# Processing Record 21 of Set 11 | sakaiminato
# Processing Record 22 of Set 11 | necochea
# Processing Record 23 of Set 11 | gonen
# Processing Record 24 of Set 11 | foumbot
# Processing Record 25 of Set 11 | chickasha
# Processing Record 26 of Set 11 | suntar
# Processing Record 27 of Set 11 | gladstone
# Processing Record 28 of Set 11 | kutum
# Processing Record 29 of Set 11 | shahe
# Processing Record 30 of Set 11 | padang
# Processing Record 31 of Set 11 | joshimath
# Processing Record 32 of Set 11 | rosita
# Processing Record 33 of Set 11 | kieta
# Processing Record 34 of Set 11 | mana
# Processing Record 35 of Set 11 | dong hoi
# Processing Record 36 of Set 11 | constantine
# Processing Record 37 of Set 11 | nanortalik
# Processing Record 38 of Set 11 | bayan
# Processing Record 39 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 40 of Set 11 | sosva
# Processing Record 41 of Set 11 | saryg-sep
# Processing Record 42 of Set 11 | saint-joseph
# Processing Record 43 of Set 11 | roswell
# Processing Record 44 of Set 11 | fengzhen
# Processing Record 45 of Set 11 | puerto baquerizo moreno
# Processing Record 46 of Set 11 | sibolga
# Processing Record 47 of Set 11 | shingu
# Processing Record 48 of Set 11 | kimbe
# Processing Record 49 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 11 | matamoros
# Processing Record 1 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 2 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 12 | chagoda
# Processing Record 4 of Set 12 | gizo
# Processing Record 5 of Set 12 | san carlos del zulia
# Processing Record 6 of Set 12 | arcachon
# Processing Record 7 of Set 12 | nantucket
# Processing Record 8 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | yenagoa
# Processing Record 10 of Set 12 | baykit
# Processing Record 11 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 12 of Set 12 | lucapa
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | vagay
# Processing Record 15 of Set 12 | dubbo
# Processing Record 16 of Set 12 | mabaruma
# Processing Record 17 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 12 | mering
# Processing Record 19 of Set 12 | chara
# Processing Record 20 of Set 12 | danjiangkou
# Processing Record 21 of Set 12 | liberal
# Processing Record 22 of Set 12 | miraflores
# Processing Record 23 of Set 12 | luganville
# Processing Record 24 of Set 12 | athgarh
# City not found. Skipping...
# Processing Record 25 of Set 12 | tukrah
# Processing Record 26 of Set 12 | burica
# City not found. Skipping...
# Processing Record 27 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 12 | grand gaube
# Processing Record 29 of Set 12 | villa carlos paz
# Processing Record 30 of Set 12 | kaspiyskiy
# Processing Record 31 of Set 12 | strezhevoy
# Processing Record 32 of Set 12 | shiraz
# Processing Record 33 of Set 12 | qaqortoq
# Processing Record 34 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 35 of Set 12 | evensk
# Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary to keep data 
weather_data = {
     "City": cities_list,
     "Cloudiness": cloudiness,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Lat": lat,
     "Lng": lng,
     "Max Temp": max_temp,
     "Wind Speed": wind_speed    
 }

# Create the data frame and count variables for each columns
weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# City          532
# Cloudiness    532
# Country       532
# Date          532
# Humidity      532
# Lat           532
# Lng           532
# Max Temp      532
# Wind Speed    532
# dtype: int64

# %%
weather_df.head()
#write dataframe to csv file
weather_df.to_csv(output_data_file,index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude and temprature
plt.scatter(weather_df["Lat"], weather_df["Max Temp"])
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temprature (F)")
plt.grid()
plt.savefig("output_data/Images/temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude and humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Speed (mph)")
plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/wind_speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearRegression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6, 0),fontsize=15,color="red")

    print(f"rvalue    = {round(rvalue, 3)}")
    print(f"r-squared = {round(rvalue**2, 3)}")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem=weather_df[weather_df['Lat']>0]
southern_hem=weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Lat'],northern_hem['Max Temp'],)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# rvalue    = -0.895
# r-squared = 0.801

# %% [markdown]
# A high negative r-value indicates a strong negative correlation between latituded and max temp.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Lat'],southern_hem['Max Temp'],)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# rvalue    = 0.651
# r-squared = 0.424

# %% [markdown]
# A high positive r-value indicates a strong positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Humidity'],northern_hem['Lat'],)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.375
# r-squared = 0.141

# %% [markdown]
# A low to medium level r-value suggests a medium level of correlation between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Humidity'],southern_hem['Lat'],)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.117
# r-squared = 0.014

# %% [markdown]
# A low r-value suggests little to no positive correlation between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Cloudiness'],northern_hem['Lat'],)
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.249
# r-squared = 0.062

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between cloudiness and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Cloudiness'],southern_hem['Lat'],)
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.388
# r-squared = 0.151

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between cloudiness and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Wind Speed'],northern_hem['Lat'],)
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.202
# r-squared = 0.041

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between wind speed and latitude for the Northen Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Wind Speed'],southern_hem['Lat'],)
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = -0.205
# r-squared = 0.042

# %% [markdown]
# A low negative r-value indicates a weak correlation between wind speed and latitude.
