# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
import matplotlib.dates as mdate
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create a base url
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

# Create the lists to hold relative data
cities_list= []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print("Started")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = base_url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    #print(response)
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase city counter
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        cities_list.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
        
print("Completed")
# Out:
# Started
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | cayenne
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | waddan
# Processing Record 10 of Set 1 | soyo
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | berlevag
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | tubinskiy
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | ponoka
# Processing Record 25 of Set 1 | salta
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | nanakuli
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | am timan
# Processing Record 32 of Set 1 | pacific grove
# Processing Record 33 of Set 1 | batsfjord
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | brownwood
# Processing Record 39 of Set 1 | elliot
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | sabang
# Processing Record 42 of Set 1 | prince rupert
# Processing Record 43 of Set 1 | homer
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | maniitsoq
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | avera
# Processing Record 2 of Set 2 | mlonggo
# Processing Record 3 of Set 2 | ler
# Processing Record 4 of Set 2 | gornopravdinsk
# Processing Record 5 of Set 2 | sao felix do xingu
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | payakumbuh
# Processing Record 9 of Set 2 | soloneshnoye
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | chino valley
# Processing Record 12 of Set 2 | zeya
# Processing Record 13 of Set 2 | ngunguru
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | la rioja
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | bignona
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | pozo colorado
# Processing Record 22 of Set 2 | sokolo
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | marsh harbour
# Processing Record 25 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 2 | tuatapere
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | carikar
# City not found. Skipping...
# Processing Record 30 of Set 2 | ebersberg
# Processing Record 31 of Set 2 | lujan
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | niamey
# Processing Record 37 of Set 2 | gamba
# Processing Record 38 of Set 2 | majene
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | talcahuano
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | pindiga
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | columbia
# Processing Record 47 of Set 2 | eyl
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 3 | nizhniy kuranakh
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | tir pol
# City not found. Skipping...
# Processing Record 4 of Set 3 | asadabad
# Processing Record 5 of Set 3 | anshun
# Processing Record 6 of Set 3 | santa cruz
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | yerbogachen
# Processing Record 9 of Set 3 | broken hill
# Processing Record 10 of Set 3 | tuyen quang
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | rio casca
# Processing Record 13 of Set 3 | iquique
# Processing Record 14 of Set 3 | dilla
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | agadez
# Processing Record 18 of Set 3 | nuqui
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | oranjemund
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | komsomolets
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | champerico
# Processing Record 26 of Set 3 | clarence town
# Processing Record 27 of Set 3 | anadyr
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | san vicente
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | vezirkopru
# Processing Record 33 of Set 3 | kapoeta
# Processing Record 34 of Set 3 | gizo
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | naliya
# Processing Record 37 of Set 3 | isiro
# Processing Record 38 of Set 3 | ugoofaaru
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | fez
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | peace river
# Processing Record 44 of Set 3 | leshukonskoye
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | rio gallegos
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | karatuzskoye
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | porto novo
# Processing Record 4 of Set 4 | saint-pierre
# Processing Record 5 of Set 4 | savalou
# Processing Record 6 of Set 4 | yelizovo
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | coihaique
# Processing Record 9 of Set 4 | melita
# Processing Record 10 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 4 | oussouye
# Processing Record 12 of Set 4 | sur
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | jamestown
# Processing Record 15 of Set 4 | mabaruma
# Processing Record 16 of Set 4 | coquimbo
# Processing Record 17 of Set 4 | opuwo
# Processing Record 18 of Set 4 | san quintin
# Processing Record 19 of Set 4 | xingyi
# Processing Record 20 of Set 4 | humberto de campos
# Processing Record 21 of Set 4 | najran
# Processing Record 22 of Set 4 | castro
# Processing Record 23 of Set 4 | ayorou
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | fougamou
# Processing Record 26 of Set 4 | luanda
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | praia
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | acaxochitlan
# Processing Record 32 of Set 4 | acapulco
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | jay
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | padang
# Processing Record 39 of Set 4 | cascais
# Processing Record 40 of Set 4 | reconquista
# Processing Record 41 of Set 4 | diffa
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | taltal
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | mitsamiouli
# Processing Record 46 of Set 4 | puerto ayacucho
# Processing Record 47 of Set 4 | stokmarknes
# Processing Record 48 of Set 4 | havre-saint-pierre
# Processing Record 49 of Set 4 | vila franca do campo
# Processing Record 50 of Set 4 | rovaniemi
# Processing Record 1 of Set 5 | bambous virieux
# Processing Record 2 of Set 5 | rio cuarto
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 5 | udachnyy
# Processing Record 6 of Set 5 | sabha
# Processing Record 7 of Set 5 | nanchang
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | walvis bay
# Processing Record 10 of Set 5 | claresholm
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | nianzishan
# Processing Record 13 of Set 5 | kununurra
# Processing Record 14 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 5 | los llanos de aridane
# Processing Record 16 of Set 5 | bayevo
# Processing Record 17 of Set 5 | trofors
# Processing Record 18 of Set 5 | mustasaari
# Processing Record 19 of Set 5 | xiangdong
# City not found. Skipping...
# Processing Record 20 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | sistranda
# Processing Record 26 of Set 5 | luba
# Processing Record 27 of Set 5 | corbu
# Processing Record 28 of Set 5 | searcy
# Processing Record 29 of Set 5 | boyabat
# Processing Record 30 of Set 5 | makakilo city
# Processing Record 31 of Set 5 | uruzgan
# Processing Record 32 of Set 5 | luxor
# Processing Record 33 of Set 5 | meulaboh
# Processing Record 34 of Set 5 | moranbah
# Processing Record 35 of Set 5 | yulara
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | vardo
# Processing Record 39 of Set 5 | ust-karsk
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | meadow lake
# Processing Record 43 of Set 5 | dwarka
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 5 | soavinandriana
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | mar del plata
# Processing Record 49 of Set 5 | beaufort
# Processing Record 50 of Set 5 | partenit
# Processing Record 1 of Set 6 | brigantine
# Processing Record 2 of Set 6 | salinopolis
# Processing Record 3 of Set 6 | smithers
# Processing Record 4 of Set 6 | kirishi
# Processing Record 5 of Set 6 | kiama
# Processing Record 6 of Set 6 | dori
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | kovdor
# Processing Record 9 of Set 6 | ponta delgada
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | sinnamary
# Processing Record 12 of Set 6 | half moon bay
# Processing Record 13 of Set 6 | goderich
# Processing Record 14 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 6 | hanzhong
# Processing Record 16 of Set 6 | ulaangom
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | nyurba
# Processing Record 19 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 6 | canazas
# Processing Record 21 of Set 6 | senno
# Processing Record 22 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 6 | cururupu
# Processing Record 24 of Set 6 | sayhat
# Processing Record 25 of Set 6 | weinan
# Processing Record 26 of Set 6 | lasa
# Processing Record 27 of Set 6 | watertown
# Processing Record 28 of Set 6 | santiago
# Processing Record 29 of Set 6 | traralgon
# Processing Record 30 of Set 6 | mariinsk
# Processing Record 31 of Set 6 | aksha
# Processing Record 32 of Set 6 | loanda
# Processing Record 33 of Set 6 | poum
# Processing Record 34 of Set 6 | jodiya
# Processing Record 35 of Set 6 | tsiroanomandidy
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | alta floresta
# Processing Record 38 of Set 6 | emerald
# Processing Record 39 of Set 6 | celestun
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | marrakesh
# Processing Record 42 of Set 6 | vila
# Processing Record 43 of Set 6 | valparaiso
# Processing Record 44 of Set 6 | kutum
# Processing Record 45 of Set 6 | muzhi
# Processing Record 46 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 6 | sorong
# Processing Record 48 of Set 6 | burica
# City not found. Skipping...
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | zapolyarnyy
# Processing Record 1 of Set 7 | morant bay
# Processing Record 2 of Set 7 | ati
# Processing Record 3 of Set 7 | do gonbadan
# Processing Record 4 of Set 7 | toora-khem
# Processing Record 5 of Set 7 | adrar
# Processing Record 6 of Set 7 | matagami
# Processing Record 7 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 7 | kapit
# Processing Record 9 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 7 | port jervis
# Processing Record 11 of Set 7 | garhakota
# Processing Record 12 of Set 7 | tadine
# Processing Record 13 of Set 7 | caravelas
# Processing Record 14 of Set 7 | laguna
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | saint anthony
# Processing Record 17 of Set 7 | halifax
# Processing Record 18 of Set 7 | severo-yeniseyskiy
# Processing Record 19 of Set 7 | verkhnevilyuysk
# Processing Record 20 of Set 7 | bundaberg
# Processing Record 21 of Set 7 | alghero
# Processing Record 22 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 7 | lethem
# Processing Record 24 of Set 7 | preobrazheniye
# Processing Record 25 of Set 7 | bandarbeyla
# Processing Record 26 of Set 7 | tangzhai
# Processing Record 27 of Set 7 | pochutla
# Processing Record 28 of Set 7 | atambua
# Processing Record 29 of Set 7 | morros
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | lichinga
# Processing Record 34 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 7 | chimbote
# Processing Record 36 of Set 7 | kargasok
# Processing Record 37 of Set 7 | barberino di mugello
# Processing Record 38 of Set 7 | benguela
# Processing Record 39 of Set 7 | saint george
# Processing Record 40 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | the pas
# Processing Record 42 of Set 7 | jiuquan
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | kirkenaer
# Processing Record 45 of Set 7 | dondo
# Processing Record 46 of Set 7 | vulcan
# Processing Record 47 of Set 7 | xuddur
# Processing Record 48 of Set 7 | tanout
# Processing Record 49 of Set 7 | brae
# Processing Record 50 of Set 7 | tiarei
# Processing Record 1 of Set 8 | olafsvik
# Processing Record 2 of Set 8 | ayan
# Processing Record 3 of Set 8 | cordoba
# Processing Record 4 of Set 8 | tonj
# Processing Record 5 of Set 8 | tigil
# Processing Record 6 of Set 8 | hirara
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | pecos
# Processing Record 9 of Set 8 | mogok
# Processing Record 10 of Set 8 | sandakan
# Processing Record 11 of Set 8 | terra nova
# Processing Record 12 of Set 8 | stornoway
# Processing Record 13 of Set 8 | pevek
# Processing Record 14 of Set 8 | ahmadpur east
# Processing Record 15 of Set 8 | abu dhabi
# Processing Record 16 of Set 8 | primore
# City not found. Skipping...
# Processing Record 17 of Set 8 | turukhansk
# Processing Record 18 of Set 8 | bilma
# Processing Record 19 of Set 8 | straumen
# Processing Record 20 of Set 8 | ribeira grande
# Processing Record 21 of Set 8 | vila velha
# Processing Record 22 of Set 8 | haines junction
# Processing Record 23 of Set 8 | dunedin
# Processing Record 24 of Set 8 | great yarmouth
# Processing Record 25 of Set 8 | usinsk
# Processing Record 26 of Set 8 | turiacu
# Processing Record 27 of Set 8 | amapa
# Processing Record 28 of Set 8 | safaga
# Processing Record 29 of Set 8 | kletskaya
# Processing Record 30 of Set 8 | trebur
# Processing Record 31 of Set 8 | bembereke
# Processing Record 32 of Set 8 | caratinga
# Processing Record 33 of Set 8 | kargopol
# Processing Record 34 of Set 8 | markova
# Processing Record 35 of Set 8 | kaka
# Processing Record 36 of Set 8 | iwanai
# Processing Record 37 of Set 8 | japura
# Processing Record 38 of Set 8 | santo tomas
# Processing Record 39 of Set 8 | santa maria del oro
# Processing Record 40 of Set 8 | qandala
# Processing Record 41 of Set 8 | mackay
# Processing Record 42 of Set 8 | iqaluit
# Processing Record 43 of Set 8 | pitimbu
# Processing Record 44 of Set 8 | dawei
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | wanaka
# Processing Record 47 of Set 8 | nesna
# Processing Record 48 of Set 8 | tigzirt
# Processing Record 49 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 8 | florence
# Processing Record 1 of Set 9 | hervey bay
# Processing Record 2 of Set 9 | mackenzie
# Processing Record 3 of Set 9 | alamosa
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | kahului
# Processing Record 6 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | imeni stepana razina
# Processing Record 9 of Set 9 | copala
# Processing Record 10 of Set 9 | sola
# Processing Record 11 of Set 9 | wanning
# Processing Record 12 of Set 9 | seoul
# Processing Record 13 of Set 9 | goalpara
# Processing Record 14 of Set 9 | saint-joseph
# Processing Record 15 of Set 9 | vallenar
# Processing Record 16 of Set 9 | urk
# Processing Record 17 of Set 9 | grand gaube
# Processing Record 18 of Set 9 | bahia honda
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | moerai
# Processing Record 21 of Set 9 | danshui
# Processing Record 22 of Set 9 | kihei
# Processing Record 23 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | veshkayma
# Processing Record 26 of Set 9 | viedma
# Processing Record 27 of Set 9 | hamilton
# Processing Record 28 of Set 9 | ahmadnagar
# Processing Record 29 of Set 9 | ponta do sol
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | rumonge
# Processing Record 32 of Set 9 | davila
# Processing Record 33 of Set 9 | altea
# Processing Record 34 of Set 9 | evensk
# Processing Record 35 of Set 9 | verkhnyaya inta
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | merauke
# Processing Record 38 of Set 9 | olinda
# Processing Record 39 of Set 9 | ozernovskiy
# Processing Record 40 of Set 9 | bengkulu
# Processing Record 41 of Set 9 | enschede
# Processing Record 42 of Set 9 | vanimo
# Processing Record 43 of Set 9 | wajir
# Processing Record 44 of Set 9 | lagos
# Processing Record 45 of Set 9 | axim
# Processing Record 46 of Set 9 | santa ana
# Processing Record 47 of Set 9 | yaan
# Processing Record 48 of Set 9 | portland
# Processing Record 49 of Set 9 | praia da vitoria
# Processing Record 50 of Set 9 | tommot
# Processing Record 1 of Set 10 | byron bay
# Processing Record 2 of Set 10 | mersing
# Processing Record 3 of Set 10 | port lincoln
# Processing Record 4 of Set 10 | hit
# Processing Record 5 of Set 10 | marienburg
# Processing Record 6 of Set 10 | matola
# Processing Record 7 of Set 10 | boyolangu
# Processing Record 8 of Set 10 | atherton
# Processing Record 9 of Set 10 | nhulunbuy
# Processing Record 10 of Set 10 | channel-port aux basques
# Processing Record 11 of Set 10 | baghdad
# Processing Record 12 of Set 10 | hun
# Processing Record 13 of Set 10 | kumluca
# Processing Record 14 of Set 10 | batagay-alyta
# Processing Record 15 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 10 | salalah
# Processing Record 17 of Set 10 | lianzhou
# Processing Record 18 of Set 10 | yumen
# Processing Record 19 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | tubuala
# Processing Record 21 of Set 10 | marmarion
# Processing Record 22 of Set 10 | sanchor
# Processing Record 23 of Set 10 | baksheyevo
# Processing Record 24 of Set 10 | pizarro
# Processing Record 25 of Set 10 | great falls
# Processing Record 26 of Set 10 | kilindoni
# Processing Record 27 of Set 10 | mareeba
# Processing Record 28 of Set 10 | constitucion
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | kolokani
# Processing Record 31 of Set 10 | biograd na moru
# Processing Record 32 of Set 10 | san luis
# Processing Record 33 of Set 10 | dingle
# Processing Record 34 of Set 10 | fiche
# Processing Record 35 of Set 10 | richards bay
# Processing Record 36 of Set 10 | satkhira
# Processing Record 37 of Set 10 | dhidhdhoo
# Processing Record 38 of Set 10 | vanavara
# Processing Record 39 of Set 10 | kieta
# Processing Record 40 of Set 10 | stekolnyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | copiapo
# Processing Record 42 of Set 10 | presidencia roque saenz pena
# Processing Record 43 of Set 10 | mehran
# Processing Record 44 of Set 10 | kawhia
# Processing Record 45 of Set 10 | shelburne
# Processing Record 46 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 10 | sao raimundo nonato
# Processing Record 48 of Set 10 | almaznyy
# Processing Record 49 of Set 10 | husavik
# Processing Record 50 of Set 10 | tumut
# Processing Record 1 of Set 11 | dicabisagan
# Processing Record 2 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 11 | bara
# Processing Record 4 of Set 11 | yarensk
# Processing Record 5 of Set 11 | anan
# Processing Record 6 of Set 11 | cabo san lucas
# Processing Record 7 of Set 11 | omboue
# Processing Record 8 of Set 11 | kudahuvadhoo
# Processing Record 9 of Set 11 | dalvik
# Processing Record 10 of Set 11 | samarai
# Processing Record 11 of Set 11 | stony plain
# Processing Record 12 of Set 11 | arlit
# Processing Record 13 of Set 11 | kuala sungai baru
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | gat
# Processing Record 16 of Set 11 | nova olinda do norte
# Processing Record 17 of Set 11 | kawalu
# Processing Record 18 of Set 11 | erenhot
# Processing Record 19 of Set 11 | urumqi
# Processing Record 20 of Set 11 | bage
# Processing Record 21 of Set 11 | port macquarie
# Processing Record 22 of Set 11 | mocuba
# Processing Record 23 of Set 11 | vao
# Processing Record 24 of Set 11 | casino
# Processing Record 25 of Set 11 | binzhou
# Processing Record 26 of Set 11 | bull savanna
# Processing Record 27 of Set 11 | mawlaik
# Processing Record 28 of Set 11 | tilichiki
# Processing Record 29 of Set 11 | berea
# Processing Record 30 of Set 11 | tautira
# Processing Record 31 of Set 11 | nelson bay
# Processing Record 32 of Set 11 | umm kaddadah
# Processing Record 33 of Set 11 | buraydah
# Processing Record 34 of Set 11 | gautier
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 11 | khasan
# Processing Record 38 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 39 of Set 11 | banyo
# Processing Record 40 of Set 11 | spokane
# Processing Record 41 of Set 11 | skibbereen
# Processing Record 42 of Set 11 | hambantota
# Processing Record 43 of Set 11 | batagay
# Processing Record 44 of Set 11 | grindavik
# Processing Record 45 of Set 11 | nishihara
# Processing Record 46 of Set 11 | trelew
# Processing Record 47 of Set 11 | tlacotepec
# Processing Record 48 of Set 11 | fairview
# Processing Record 49 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 11 | ulladulla
# Processing Record 1 of Set 12 | basco
# Processing Record 2 of Set 12 | jiaozuo
# Processing Record 3 of Set 12 | awbari
# Processing Record 4 of Set 12 | payo
# Processing Record 5 of Set 12 | warrnambool
# Processing Record 6 of Set 12 | tignapoloan
# City not found. Skipping...
# Processing Record 7 of Set 12 | camargo
# Processing Record 8 of Set 12 | juegang
# Processing Record 9 of Set 12 | santa eulalia
# Processing Record 10 of Set 12 | puerto carreno
# Processing Record 11 of Set 12 | babstovo
# Processing Record 12 of Set 12 | idah
# Processing Record 13 of Set 12 | leningradskiy
# Processing Record 14 of Set 12 | grand forks
# Processing Record 15 of Set 12 | namibe
# Processing Record 16 of Set 12 | flinders
# Processing Record 17 of Set 12 | saint-max
# Processing Record 18 of Set 12 | charters towers
# Processing Record 19 of Set 12 | aromashevo
# Processing Record 20 of Set 12 | istok
# Processing Record 21 of Set 12 | saint-augustin
# Processing Record 22 of Set 12 | antalaha
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | teya
# Processing Record 25 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 12 | nemuro
# Processing Record 27 of Set 12 | pemangkat
# Processing Record 28 of Set 12 | sterlibashevo
# Processing Record 29 of Set 12 | fort frances
# Processing Record 30 of Set 12 | uvinza
# Processing Record 31 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 32 of Set 12 | ojinaga
# Processing Record 33 of Set 12 | babati
# Processing Record 34 of Set 12 | te anau
# Processing Record 35 of Set 12 | east millcreek
# Processing Record 36 of Set 12 | snasa
# Processing Record 37 of Set 12 | ilyich
# Processing Record 38 of Set 12 | batemans bay
# Processing Record 39 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 12 | sioux city
# Processing Record 41 of Set 12 | havelock
# Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary to keep data 
weather_data = {
     "City": cities_list,
     "Cloudiness": cloudiness,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Lat": lat,
     "Lng": lng,
     "Max Temp": max_temp,
     "Wind Speed": wind_speed    
 }

# Create the data frame and count variables for each columns
weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# City          540
# Cloudiness    540
# Country       540
# Date          540
# Humidity      540
# Lat           540
# Lng           540
# Max Temp      540
# Wind Speed    540
# dtype: int64

# %%
weather_df.head()
#write dataframe to csv file
weather_df.to_csv(output_data_file,index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude and temprature
plt.scatter(weather_df["Lat"], weather_df["Max Temp"])
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temprature (F)")
plt.grid()
plt.savefig("output_data/Images/temperature.png")
plt.show()

# %% [markdown]
# The code above is comparing the latitude and max temp of the cities from the weather_df. The chart shows a negative correlation between Latitude and Max Temp. As the lattiude gets further from 0, that the max temp decreases and the highest max temps are at Latitude 0.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude and humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/humidity.png")
plt.show()

# %% [markdown]
# The code above is comparing the latitude and humidty of the cities from the weather_df. The chart shows little to no correlation between latitude and humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/cloudiness.png")
plt.show()

# %% [markdown]
# The code above is comparing the latitude and cloudinees of the cities from the weather_df. The chart shows little to no correlation between latitude and cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Speed (mph)")
plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("output_data/Images/wind_speed.png")
plt.show()

# %% [markdown]
# The code above is comparing the latitude and windspeed of the cities from the weather_df. The chart shows little to no postive correlation between windspeed and latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearRegression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,1)) + "x + " + str(round(intercept,1))

    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6, 0),fontsize=15,color="red")

    print(f"rvalue    = {round(rvalue, 3)}")
    print(f"r-squared = {round(rvalue**2, 3)}")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem=weather_df[weather_df['Lat']>0]
southern_hem=weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Lat'],northern_hem['Max Temp'],)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# rvalue    = -0.908
# r-squared = 0.824

# %% [markdown]
# A high negative r-value indicates a strong negative correlation between latituded and max temp.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Lat'],southern_hem['Max Temp'],)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# rvalue    = 0.667
# r-squared = 0.445

# %% [markdown]
# A high positive r-value indicates a strong positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Humidity'],northern_hem['Lat'],)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.395
# r-squared = 0.156

# %% [markdown]
# A low to medium level r-value suggests a medium level of correlation between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Humidity'],southern_hem['Lat'],)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.155
# r-squared = 0.024

# %% [markdown]
# A low r-value suggests little to no positive correlation between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Cloudiness'],northern_hem['Lat'],)
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.237
# r-squared = 0.056

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between cloudiness and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Cloudiness'],southern_hem['Lat'],)
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.387
# r-squared = 0.15

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between cloudiness and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(northern_hem['Wind Speed'],northern_hem['Lat'],)
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = 0.216
# r-squared = 0.046

# %% [markdown]
# A low positive r-value indicates a weak positive correlation between wind speed and latitude for the Northen Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(southern_hem['Wind Speed'],southern_hem['Lat'],)
plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
plt.show()
# Out:
# rvalue    = -0.18
# r-squared = 0.032

# %% [markdown]
# A low negative r-value indicates a weak correlation between wind speed and latitude.
